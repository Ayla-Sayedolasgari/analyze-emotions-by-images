# %%
# !pip install -q matplotlib transformers pillow google-colab

from transformers import pipeline
from PIL import Image
from google.colab import files
import matplotlib.pyplot as plt

# -----------------------------
# بارگذاری مدل
# -----------------------------
classifier = pipeline("image-classification", model="dima806/facial_emotions_image_detection")

# -----------------------------
# آپلود عکس
# -----------------------------
print("📌 لطفاً یک عکس انتخاب و آپلود کنید:")
uploaded = files.upload()
image_path = list(uploaded.keys())[0]

# باز کردن و نمایش عکس
image = Image.open(image_path)
display(image)

# -----------------------------
# تحلیل احساسات
# -----------------------------
results = classifier(image)

# چاپ نتایج در کنسول
print("\n📌 نتایج تحلیل احساسات:")
labels = []
scores = []

for res in results:
    print(f"{res['label']}: {res['score']:.4f}")
    labels.append(res['label'])
    scores.append(res['score'])

# -----------------------------
# رسم نمودار دایره‌ای
# -----------------------------
plt.figure(figsize=(6,6))
plt.pie(scores, labels=labels, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.title("results")
plt.show()
# Out:
# Device set to use cpu
# 📌 لطفاً یک عکس انتخاب و آپلود کنید:
#      <input type="file" id="files-8abd5016-81b4-4f72-9d57-b55721799a7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8abd5016-81b4-4f72-9d57-b55721799a7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
